# %% [markdown]
# ## Desafio 7 - Desafio APIs

# %% [markdown]
# La API que se va a utilizar en el notebook es una API del Gobierno de EEUU, mas precisamente del Departamento de Salud y Servicios Humanos, dentro de ella, de la Oficina de Prevención de Enfermedades y Promoción de la Salud. El sitio principal del organismo es:
# https://health.gov/
#
# La url de donde se obtiene información de la API es:
# https://health.gov/our-work/national-health-initiatives/health-literacy/consumer-health-content/free-web-content/apis-developers/how-use-api
#
# Lo interesante de la API es que tiene un listado de tópicos y a su vez dentro de cada tópico hay una API con data del mismo, hasta se puede seleccionar el idioma esto es pasandolo como parámetro en la url. Es decir puedo hacer una consulta al API general o aun API específico y hasta se puede parametrizar un poco a la consulta.

# %% [markdown]
# ### Consulta a la API principal

# %%
import pandas as pd
import requests as rq
import json

# %%
url = 'https://health.gov/myhealthfinder/api/v3/itemlist.json?Type=topic'

data = rq.get(url)

data
# Out:
# <Response [200]>

# %% [markdown]
# Se observa que el status code es 200 por lo tanto esta todo ok.

# %%
data_json = json.loads(data.text)

data_json
# Out:
# {'Result': {'Error': 'False',
#   'Total': 100,
#   'Query': {'ApiVersion': '3',
#    'ApiType': 'itemlist',
#    'TopicId': None,
#    'ToolId': None,
#    'CategoryId': None,
#    'PopulationId': None,
#    'Keyword': None,
#    'Who': None,
#    'Age': None,
#    'Sex': None,
#    'Pregnant': None,
#    'TobaccoUse': None,
#    'SexuallyActive': None,
#    'Category': None,
#    'Lang': 'en',
#    'Type': 'topic',
#    'ReturnType': 'json',
#    'Callback': None,
#    'HealthfinderPage': None,
#    'APiType': 'itemlist'},
#   'Language': 'English',
#   'Items': {'Item': [{'Type': 'Topic',
#      'Id': '25',
#      'Title': 'Keep Your Heart Healthy',
#      'ParentId': -1,
#      'TranslationId': '25'},
#     {'Type': 'Topic',
#      'Id': '327',
#      'Title': 'Get Enough Folic Acid',
#      'ParentId': -1,
#      'TranslationId': '327'},
#     {'Type': 'Topic',
#      'Id': '329',
#      'Title': 'Lower Your Risk of Falling',
#      'ParentId': -1,
#      'TranslationId': '329'},
#     {'Type': 'Topic',
#      'Id': '350',
#      'Title': 'Get Tested for Chlamydia and Gonorrhea',
#      'ParentId': -1,
#      'TranslationId': '350'},
#     {'Type': 'Topic',
#      'Id': '510',
#      'Title': 'Make the Most of Your Baby’s Visit to the Doctor (Ages 0 to 11 Months) ',
#      'ParentId': -1,
#      'TranslationId': '510'},
#     {'Type': 'Topic',
#      'Id': '512',
#      'Title': 'Make the Most of Your Child’s Visit to the Doctor (Ages 1 to 4)',
#      'ParentId': -1,
#      'TranslationId': '512'},
#     {'Type': 'Topic',
#      'Id': '514',
#      'Title': 'Get Tested for Breast Cancer',
#      'ParentId': -1,
#      'TranslationId': '514'},
#     {'Type': 'Topic',
#      'Id': '527',
#      'Title': 'Make the Most of Your Child’s Visit to the Doctor (Ages 5 to 10)',
#      'ParentId': -1,
#      'TranslationId': '527'},
#     {'Type': 'Topic',
#      'Id': '528',
#      'Title': 'Make the Most of Your Child’s Visit to the Doctor (Ages 11 to 14)',
#      'ParentId': -1,
#      'TranslationId': '528'},
#     {'Type': 'Topic',
#      'Id': '529',
#      'Title': 'Make the Most of Your Teen’s Visit to the Doctor (Ages 15 to 17)',
#      'ParentId': -1,
#      'TranslationId': '529'},
#     {'Type': 'Topic',
#      'Id': '530',
#      'Title': "Take Care of Your Child's Teeth",
#      'ParentId': -1,
#      'TranslationId': '530'},
#     {'Type': 'Topic',
#      'Id': '531',
#      'Title': 'Get Screened',
#      'ParentId': -1,
#      'TranslationId': '531'},
#     {'Type': 'Topic',
#      'Id': '532',
#      'Title': 'Talk to Your Doctor About Abdominal Aortic Aneurysm',
#      'ParentId': -1,
#      'TranslationId': '532'},
#     {'Type': 'Topic',
#      'Id': '533',
#      'Title': 'Get Your Blood Pressure Checked',
#      'ParentId': -1,
#      'TranslationId': '533'},
#     {'Type': 'Topic',
#      'Id': '534',
#      'Title': 'Get a Bone Density Test',
#      'ParentId': -1,
#      'TranslationId': '534'},
#     {'Type': 'Topic',
#      'Id': '536',
#      'Title': 'Get Screened for Cervical Cancer',
#      'ParentId': -1,
#      'TranslationId': '536'},
#     {'Type': 'Topic',
#      'Id': '537',
#      'Title': 'Get Your Cholesterol Checked',
#      'ParentId': -1,
#      'TranslationId': '537'},
#     {'Type': 'Topic',
#      'Id': '538',
#      'Title': 'Get Tested for Colorectal Cancer',
#      'ParentId': -1,
#      'TranslationId': '538'},
#     {'Type': 'Topic',
#      'Id': '539',
#      'Title': 'Get Your Teen Screened for Depression',
#      'ParentId': -1,
#      'TranslationId': '539'},
#     {'Type': 'Topic',
#      'Id': '540',
#      'Title': 'Talk with Your Doctor About Depression',
#      'ParentId': -1,
#      'TranslationId': '540'},
#     {'Type': 'Topic',
#      'Id': '541',
#      'Title': 'Get Your Child’s Vision Checked',
#      'ParentId': -1,
#      'TranslationId': '541'},
#     {'Type': 'Topic',
#      'Id': '542',
#      'Title': 'Get Vaccines to Protect Your Health (Adults Age 50 or Older)',
#      'ParentId': -1,
#      'TranslationId': '542'},
#     {'Type': 'Topic',
#      'Id': '543',
#      'Title': 'Get Vaccines to Protect Your Health (Adults Ages 19 to 49)',
#      'ParentId': -1,
#      'TranslationId': '543'},
#     {'Type': 'Topic',
#      'Id': '544',
#      'Title': 'Get Your Child the HPV Vaccine',
#      'ParentId': -1,
#      'TranslationId': '544'},
#     {'Type': 'Topic',
#      'Id': '546',
#      'Title': 'Get Your Child’s Vaccines on Schedule',
#      'ParentId': -1,
#      'TranslationId': '546'},
#     {'Type': 'Topic',
#      'Id': '547',
#      'Title': 'Talk with a Doctor if Breast or Ovarian Cancer Runs in Your Family',
#      'ParentId': -1,
#      'TranslationId': '547'},
#     {'Type': 'Topic',
#      'Id': '549',
#      'Title': 'Get Your Pre‑teen’s Vaccines on Schedule',
#      'ParentId': -1,
#      'TranslationId': '549'},
#     {'Type': 'Topic',
#      'Id': '551',
#      'Title': 'Protect Yourself from Seasonal Flu',
#      'ParentId': -1,
#      'TranslationId': '551'},
#     {'Type': 'Topic',
#      'Id': '552',
#      'Title': 'Take Charge of Your Health Care',
#      'ParentId': -1,
#      'TranslationId': '552'},
#     {'Type': 'Topic',
#      'Id': '553',
#      'Title': 'Colorectal Cancer Screening: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '553'},
#     {'Type': 'Topic',
#      'Id': '30530',
#      'Title': 'Get Enough Calcium',
#      'ParentId': -1,
#      'TranslationId': '30530'},
#     {'Type': 'Topic',
#      'Id': '30531',
#      'Title': 'Protect Your Health As You Grow Older',
#      'ParentId': -1,
#      'TranslationId': '30531'},
#     {'Type': 'Topic',
#      'Id': '30532',
#      'Title': 'Take Steps to Prevent Skin Cancer',
#      'ParentId': -1,
#      'TranslationId': '30532'},
#     {'Type': 'Topic',
#      'Id': '30533',
#      'Title': 'Get Enough Sleep',
#      'ParentId': -1,
#      'TranslationId': '30533'},
#     {'Type': 'Topic',
#      'Id': '30534',
#      'Title': "Get Support If You're a Caregiver",
#      'ParentId': -1,
#      'TranslationId': '30534'},
#     {'Type': 'Topic',
#      'Id': '30535',
#      'Title': 'Talk to Your Kids About Tobacco, Alcohol, and Drugs',
#      'ParentId': -1,
#      'TranslationId': '30535'},
#     {'Type': 'Topic',
#      'Id': '30536',
#      'Title': 'Take Steps to Prevent Type 2 Diabetes',
#      'ParentId': -1,
#      'TranslationId': '30536'},
#     {'Type': 'Topic',
#      'Id': '30537',
#      'Title': 'Watch for Warning Signs of Relationship Violence',
#      'ParentId': -1,
#      'TranslationId': '30537'},
#     {'Type': 'Topic',
#      'Id': '30538',
#      'Title': 'Choose the Right Birth Control',
#      'ParentId': -1,
#      'TranslationId': '30538'},
#     {'Type': 'Topic',
#      'Id': '30539',
#      'Title': 'Eat Healthy',
#      'ParentId': -1,
#      'TranslationId': '30539'},
#     {'Type': 'Topic',
#      'Id': '30540',
#      'Title': 'Get Your Well-Woman Visit Every Year',
#      'ParentId': -1,
#      'TranslationId': '30540'},
#     {'Type': 'Topic',
#      'Id': '30541',
#      'Title': 'Men: Take Charge of Your Health',
#      'ParentId': -1,
#      'TranslationId': '30541'},
#     {'Type': 'Topic',
#      'Id': '30542',
#      'Title': 'Talk to Your Kids About Sex and Healthy Relationships',
#      'ParentId': -1,
#      'TranslationId': '30542'},
#     {'Type': 'Topic',
#      'Id': '30543',
#      'Title': 'Prevent Back Pain',
#      'ParentId': -1,
#      'TranslationId': '30543'},
#     {'Type': 'Topic',
#      'Id': '30544',
#      'Title': 'Talk with Your Doctor About Taking Aspirin to Prevent Disease',
#      'ParentId': -1,
#      'TranslationId': '30544'},
#     {'Type': 'Topic',
#      'Id': '30545',
#      'Title': 'Prevent Infections When You Get Medical Care',
#      'ParentId': -1,
#      'TranslationId': '30545'},
#     {'Type': 'Topic',
#      'Id': '30546',
#      'Title': 'Use Medicines Safely',
#      'ParentId': -1,
#      'TranslationId': '30546'},
#     {'Type': 'Topic',
#      'Id': '30547',
#      'Title': 'Get Active',
#      'ParentId': -1,
#      'TranslationId': '30547'},
#     {'Type': 'Topic',
#      'Id': '30548',
#      'Title': 'Have a Healthy Pregnancy',
#      'ParentId': -1,
#      'TranslationId': '30548'},
#     {'Type': 'Topic',
#      'Id': '30549',
#      'Title': 'Talk with Your Doctor About Newborn Screening',
#      'ParentId': -1,
#      'TranslationId': '30549'},
#     {'Type': 'Topic',
#      'Id': '30550',
#      'Title': 'Breastfeed Your Baby',
#      'ParentId': -1,
#      'TranslationId': '30550'},
#     {'Type': 'Topic',
#      'Id': '30551',
#      'Title': 'Watch Your Weight',
#      'ParentId': -1,
#      'TranslationId': '30551'},
#     {'Type': 'Topic',
#      'Id': '30558',
#      'Title': 'Drink Alcohol Only in Moderation',
#      'ParentId': -1,
#      'TranslationId': '30558'},
#     {'Type': 'Topic',
#      'Id': '30559',
#      'Title': 'Eat Less Sodium: Quick Tips',
#      'ParentId': -1,
#      'TranslationId': '30559'},
#     {'Type': 'Topic',
#      'Id': '30560',
#      'Title': 'Manage Stress',
#      'ParentId': -1,
#      'TranslationId': '30560'},
#     {'Type': 'Topic',
#      'Id': '30561',
#      'Title': 'Reduce Your Risk of Stroke',
#      'ParentId': -1,
#      'TranslationId': '30561'},
#     {'Type': 'Topic',
#      'Id': '30562',
#      'Title': 'Talk with Your Teen About Preventing STDs',
#      'ParentId': -1,
#      'TranslationId': '30562'},
#     {'Type': 'Topic',
#      'Id': '30564',
#      'Title': 'Get Tested for HIV',
#      'ParentId': -1,
#      'TranslationId': '30564'},
#     {'Type': 'Topic',
#      'Id': '30565',
#      'Title': 'Protect Yourself from Hepatitis B',
#      'ParentId': -1,
#      'TranslationId': '30565'},
#     {'Type': 'Topic',
#      'Id': '30566',
#      'Title': 'Help Your Child Stay at a Healthy Weight',
#      'ParentId': -1,
#      'TranslationId': '30566'},
#     {'Type': 'Topic',
#      'Id': '30567',
#      'Title': 'Get Your Medicare Wellness Visit Every Year',
#      'ParentId': -1,
#      'TranslationId': '30567'},
#     {'Type': 'Topic',
#      'Id': '30574',
#      'Title': 'Gestational Diabetes Screening: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30574'},
#     {'Type': 'Topic',
#      'Id': '30575',
#      'Title': 'Hepatitis C Screening: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30575'},
#     {'Type': 'Topic',
#      'Id': '30582',
#      'Title': 'Eat Healthy While Breastfeeding: Quick Tips',
#      'ParentId': -1,
#      'TranslationId': '30582'},
#     {'Type': 'Topic',
#      'Id': '30583',
#      'Title': 'Eat Healthy During Pregnancy: Quick Tips',
#      'ParentId': -1,
#      'TranslationId': '30583'},
#     {'Type': 'Topic',
#      'Id': '30584',
#      'Title': 'Genetic Testing to Learn About Your Risk of Breast and Ovarian Cancer: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30584'},
#     {'Type': 'Topic',
#      'Id': '30586',
#      'Title': 'Colorectal Cancer Screening: Conversation Starters',
#      'ParentId': -1,
#      'TranslationId': '30586'},
#     {'Type': 'Topic',
#      'Id': '30588',
#      'Title': 'Quitting Smoking: Conversation Starters',
#      'ParentId': -1,
#      'TranslationId': '30588'},
#     {'Type': 'Topic',
#      'Id': '30589',
#      'Title': 'Choosing a Doctor: Quick Tips',
#      'ParentId': -1,
#      'TranslationId': '30589'},
#     {'Type': 'Topic',
#      'Id': '30590',
#      'Title': 'Prostate Cancer Screening: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30590'},
#     {'Type': 'Topic',
#      'Id': '30591',
#      'Title': 'Oral Health for Older Adults: Quick Tips',
#      'ParentId': -1,
#      'TranslationId': '30591'},
#     {'Type': 'Topic',
#      'Id': '30592',
#      'Title': 'Lung Cancer Screening: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30592'},
#     {'Type': 'Topic',
#      'Id': '30593',
#      'Title': 'Mammograms: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30593'},
#     {'Type': 'Topic',
#      'Id': '30594',
#      'Title': 'Medicines to Prevent Heart Attack and Stroke: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30594'},
#     {'Type': 'Topic',
#      'Id': '30595',
#      'Title': 'Preventing Osteoporosis: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30595'},
#     {'Type': 'Topic',
#      'Id': '30596',
#      'Title': 'Healthy Eating: Conversation Starters',
#      'ParentId': -1,
#      'TranslationId': '30596'},
#     {'Type': 'Topic',
#      'Id': '30597',
#      'Title': 'Help a Loved One Get More Active: Quick Tips',
#      'ParentId': -1,
#      'TranslationId': '30597'},
#     {'Type': 'Topic',
#      'Id': '30598',
#      'Title': 'Losing Weight: Conversation Starters',
#      'ParentId': -1,
#      'TranslationId': '30598'},
#     {'Type': 'Topic',
#      'Id': '30599',
#      'Title': 'Lower-Sodium Foods: Shopping List',
#      'ParentId': -1,
#      'TranslationId': '30599'},
#     {'Type': 'Topic',
#      'Id': '30600',
#      'Title': 'Preventing Preeclampsia: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30600'},
#     {'Type': 'Topic',
#      'Id': '30601',
#      'Title': 'Preventing Type 2 Diabetes: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30601'},
#     {'Type': 'Topic',
#      'Id': '30602',
#      'Title': 'Heart-Healthy Foods: Shopping List',
#      'ParentId': -1,
#      'TranslationId': '30602'},
#     {'Type': 'Topic',
#      'Id': '30604',
#      'Title': 'Depression: Conversation Starters',
#      'ParentId': -1,
#      'TranslationId': '30604'},
#     {'Type': 'Topic',
#      'Id': '30605',
#      'Title': 'Heart Health: Conversation Starters',
#      'ParentId': -1,
#      'TranslationId': '30605'},
#     {'Type': 'Topic',
#      'Id': '30606',
#      'Title': 'Alcohol Use: Conversation Starters',
#      'ParentId': -1,
#      'TranslationId': '30606'},
#     {'Type': 'Topic',
#      'Id': '30607',
#      'Title': 'Calcium: Shopping List',
#      'ParentId': -1,
#      'TranslationId': '30607'},
#     {'Type': 'Topic',
#      'Id': '30608',
#      'Title': 'Healthy Snacks: Quick Tips for Parents',
#      'ParentId': -1,
#      'TranslationId': '30608'},
#     {'Type': 'Topic',
#      'Id': '30609',
#      'Title': 'Testing for Latent Tuberculosis: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30609'},
#     {'Type': 'Topic',
#      'Id': '30610',
#      'Title': 'Quit Smoking',
#      'ParentId': -1,
#      'TranslationId': '30610'},
#     {'Type': 'Topic',
#      'Id': '30612',
#      'Title': 'Testing for Syphilis: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30612'},
#     {'Type': 'Topic',
#      'Id': '30613',
#      'Title': 'HIV Testing: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30613'},
#     {'Type': 'Topic',
#      'Id': '30614',
#      'Title': 'STD Testing: Conversation Starters',
#      'ParentId': -1,
#      'TranslationId': '30614'},
#     {'Type': 'Topic',
#      'Id': '30615',
#      'Title': 'Losing Weight: Questions for the Doctor',
#      'ParentId': -1,
#      'TranslationId': '30615'},
#     {'Type': 'Topic',
#      'Id': '30616',
#      'Title': 'Stay Active As You Get Older: Quick Tips',
#      'ParentId': -1,
#      'TranslationId': '30616'},
#     {'Type': 'Topic',
#      'Id': '30617',
#      'Title': 'Stay Active During Pregnancy: Quick Tips',
#      'ParentId': -1,
#      'TranslationId': '30617'},
#     {'Type': 'Topic',
#      'Id': '30618',
#      'Title': 'Stay Active with a Disability: Quick Tips',
#      'ParentId': -1,
#      'TranslationId': '30618'},
#     {'Type': 'Topic',
#      'Id': '30759',
#      'Title': 'Preventing Falls: Conversation Starters',
#      'ParentId': -1,
#      'TranslationId': '30759'},
#     {'Type': 'Topic',
#      'Id': '30760',
#      'Title': 'Support a Loved One at the Doctor: Quick Tips',
#      'ParentId': -1,
#      'TranslationId': '30760'},
#     {'Type': 'Topic',
#      'Id': '33303',
#      'Title': 'Talk with Your Doctor About Drug Misuse',
#      'ParentId': -1,
#      'TranslationId': '33303'},
#     {'Type': 'Topic',
#      'Id': '33304',
#      'Title': 'Drug Misuse: Conversation starters',
#      'ParentId': -1,
#      'TranslationId': '33304'}]}}}

# %% [markdown]
# La url consultada vendría a ser la API principal de donde se obtiene el listado de temas o tópicos. Se puede observar como el JSON devuelto consta básicamente de dos partes una que vendría a ser una especie de encabezado y la otra parte es el listado de tópicos en si. A continuación se van a realizar algunas averiguaciones sobre este JSON.

# %%
# Mas allá de status code obtenido el propio JSON tiene una clave que devuelve si hay error en el mismo. 
data_json['Result']['Error']
# Out:
# 'False'

# %%
# Obtengo el idioma en el que es devuelto la data. Luego se hara consulta para el idioma español.
data_json['Result']['Language']
# Out:
# 'English'

# %%
# Obtengo la cantidad de tópicos. Luego se va a verificar esta info cuando el listado de tópicos sea convertido
# en dataframe.
data_json['Result']['Total']
# Out:
# 100

# %%
data_json['Result']['Items']
# Out:
# {'Item': [{'Type': 'Topic',
#    'Id': '25',
#    'Title': 'Keep Your Heart Healthy',
#    'ParentId': -1,
#    'TranslationId': '25'},
#   {'Type': 'Topic',
#    'Id': '327',
#    'Title': 'Get Enough Folic Acid',
#    'ParentId': -1,
#    'TranslationId': '327'},
#   {'Type': 'Topic',
#    'Id': '329',
#    'Title': 'Lower Your Risk of Falling',
#    'ParentId': -1,
#    'TranslationId': '329'},
#   {'Type': 'Topic',
#    'Id': '350',
#    'Title': 'Get Tested for Chlamydia and Gonorrhea',
#    'ParentId': -1,
#    'TranslationId': '350'},
#   {'Type': 'Topic',
#    'Id': '510',
#    'Title': 'Make the Most of Your Baby’s Visit to the Doctor (Ages 0 to 11 Months) ',
#    'ParentId': -1,
#    'TranslationId': '510'},
#   {'Type': 'Topic',
#    'Id': '512',
#    'Title': 'Make the Most of Your Child’s Visit to the Doctor (Ages 1 to 4)',
#    'ParentId': -1,
#    'TranslationId': '512'},
#   {'Type': 'Topic',
#    'Id': '514',
#    'Title': 'Get Tested for Breast Cancer',
#    'ParentId': -1,
#    'TranslationId': '514'},
#   {'Type': 'Topic',
#    'Id': '527',
#    'Title': 'Make the Most of Your Child’s Visit to the Doctor (Ages 5 to 10)',
#    'ParentId': -1,
#    'TranslationId': '527'},
#   {'Type': 'Topic',
#    'Id': '528',
#    'Title': 'Make the Most of Your Child’s Visit to the Doctor (Ages 11 to 14)',
#    'ParentId': -1,
#    'TranslationId': '528'},
#   {'Type': 'Topic',
#    'Id': '529',
#    'Title': 'Make the Most of Your Teen’s Visit to the Doctor (Ages 15 to 17)',
#    'ParentId': -1,
#    'TranslationId': '529'},
#   {'Type': 'Topic',
#    'Id': '530',
#    'Title': "Take Care of Your Child's Teeth",
#    'ParentId': -1,
#    'TranslationId': '530'},
#   {'Type': 'Topic',
#    'Id': '531',
#    'Title': 'Get Screened',
#    'ParentId': -1,
#    'TranslationId': '531'},
#   {'Type': 'Topic',
#    'Id': '532',
#    'Title': 'Talk to Your Doctor About Abdominal Aortic Aneurysm',
#    'ParentId': -1,
#    'TranslationId': '532'},
#   {'Type': 'Topic',
#    'Id': '533',
#    'Title': 'Get Your Blood Pressure Checked',
#    'ParentId': -1,
#    'TranslationId': '533'},
#   {'Type': 'Topic',
#    'Id': '534',
#    'Title': 'Get a Bone Density Test',
#    'ParentId': -1,
#    'TranslationId': '534'},
#   {'Type': 'Topic',
#    'Id': '536',
#    'Title': 'Get Screened for Cervical Cancer',
#    'ParentId': -1,
#    'TranslationId': '536'},
#   {'Type': 'Topic',
#    'Id': '537',
#    'Title': 'Get Your Cholesterol Checked',
#    'ParentId': -1,
#    'TranslationId': '537'},
#   {'Type': 'Topic',
#    'Id': '538',
#    'Title': 'Get Tested for Colorectal Cancer',
#    'ParentId': -1,
#    'TranslationId': '538'},
#   {'Type': 'Topic',
#    'Id': '539',
#    'Title': 'Get Your Teen Screened for Depression',
#    'ParentId': -1,
#    'TranslationId': '539'},
#   {'Type': 'Topic',
#    'Id': '540',
#    'Title': 'Talk with Your Doctor About Depression',
#    'ParentId': -1,
#    'TranslationId': '540'},
#   {'Type': 'Topic',
#    'Id': '541',
#    'Title': 'Get Your Child’s Vision Checked',
#    'ParentId': -1,
#    'TranslationId': '541'},
#   {'Type': 'Topic',
#    'Id': '542',
#    'Title': 'Get Vaccines to Protect Your Health (Adults Age 50 or Older)',
#    'ParentId': -1,
#    'TranslationId': '542'},
#   {'Type': 'Topic',
#    'Id': '543',
#    'Title': 'Get Vaccines to Protect Your Health (Adults Ages 19 to 49)',
#    'ParentId': -1,
#    'TranslationId': '543'},
#   {'Type': 'Topic',
#    'Id': '544',
#    'Title': 'Get Your Child the HPV Vaccine',
#    'ParentId': -1,
#    'TranslationId': '544'},
#   {'Type': 'Topic',
#    'Id': '546',
#    'Title': 'Get Your Child’s Vaccines on Schedule',
#    'ParentId': -1,
#    'TranslationId': '546'},
#   {'Type': 'Topic',
#    'Id': '547',
#    'Title': 'Talk with a Doctor if Breast or Ovarian Cancer Runs in Your Family',
#    'ParentId': -1,
#    'TranslationId': '547'},
#   {'Type': 'Topic',
#    'Id': '549',
#    'Title': 'Get Your Pre‑teen’s Vaccines on Schedule',
#    'ParentId': -1,
#    'TranslationId': '549'},
#   {'Type': 'Topic',
#    'Id': '551',
#    'Title': 'Protect Yourself from Seasonal Flu',
#    'ParentId': -1,
#    'TranslationId': '551'},
#   {'Type': 'Topic',
#    'Id': '552',
#    'Title': 'Take Charge of Your Health Care',
#    'ParentId': -1,
#    'TranslationId': '552'},
#   {'Type': 'Topic',
#    'Id': '553',
#    'Title': 'Colorectal Cancer Screening: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '553'},
#   {'Type': 'Topic',
#    'Id': '30530',
#    'Title': 'Get Enough Calcium',
#    'ParentId': -1,
#    'TranslationId': '30530'},
#   {'Type': 'Topic',
#    'Id': '30531',
#    'Title': 'Protect Your Health As You Grow Older',
#    'ParentId': -1,
#    'TranslationId': '30531'},
#   {'Type': 'Topic',
#    'Id': '30532',
#    'Title': 'Take Steps to Prevent Skin Cancer',
#    'ParentId': -1,
#    'TranslationId': '30532'},
#   {'Type': 'Topic',
#    'Id': '30533',
#    'Title': 'Get Enough Sleep',
#    'ParentId': -1,
#    'TranslationId': '30533'},
#   {'Type': 'Topic',
#    'Id': '30534',
#    'Title': "Get Support If You're a Caregiver",
#    'ParentId': -1,
#    'TranslationId': '30534'},
#   {'Type': 'Topic',
#    'Id': '30535',
#    'Title': 'Talk to Your Kids About Tobacco, Alcohol, and Drugs',
#    'ParentId': -1,
#    'TranslationId': '30535'},
#   {'Type': 'Topic',
#    'Id': '30536',
#    'Title': 'Take Steps to Prevent Type 2 Diabetes',
#    'ParentId': -1,
#    'TranslationId': '30536'},
#   {'Type': 'Topic',
#    'Id': '30537',
#    'Title': 'Watch for Warning Signs of Relationship Violence',
#    'ParentId': -1,
#    'TranslationId': '30537'},
#   {'Type': 'Topic',
#    'Id': '30538',
#    'Title': 'Choose the Right Birth Control',
#    'ParentId': -1,
#    'TranslationId': '30538'},
#   {'Type': 'Topic',
#    'Id': '30539',
#    'Title': 'Eat Healthy',
#    'ParentId': -1,
#    'TranslationId': '30539'},
#   {'Type': 'Topic',
#    'Id': '30540',
#    'Title': 'Get Your Well-Woman Visit Every Year',
#    'ParentId': -1,
#    'TranslationId': '30540'},
#   {'Type': 'Topic',
#    'Id': '30541',
#    'Title': 'Men: Take Charge of Your Health',
#    'ParentId': -1,
#    'TranslationId': '30541'},
#   {'Type': 'Topic',
#    'Id': '30542',
#    'Title': 'Talk to Your Kids About Sex and Healthy Relationships',
#    'ParentId': -1,
#    'TranslationId': '30542'},
#   {'Type': 'Topic',
#    'Id': '30543',
#    'Title': 'Prevent Back Pain',
#    'ParentId': -1,
#    'TranslationId': '30543'},
#   {'Type': 'Topic',
#    'Id': '30544',
#    'Title': 'Talk with Your Doctor About Taking Aspirin to Prevent Disease',
#    'ParentId': -1,
#    'TranslationId': '30544'},
#   {'Type': 'Topic',
#    'Id': '30545',
#    'Title': 'Prevent Infections When You Get Medical Care',
#    'ParentId': -1,
#    'TranslationId': '30545'},
#   {'Type': 'Topic',
#    'Id': '30546',
#    'Title': 'Use Medicines Safely',
#    'ParentId': -1,
#    'TranslationId': '30546'},
#   {'Type': 'Topic',
#    'Id': '30547',
#    'Title': 'Get Active',
#    'ParentId': -1,
#    'TranslationId': '30547'},
#   {'Type': 'Topic',
#    'Id': '30548',
#    'Title': 'Have a Healthy Pregnancy',
#    'ParentId': -1,
#    'TranslationId': '30548'},
#   {'Type': 'Topic',
#    'Id': '30549',
#    'Title': 'Talk with Your Doctor About Newborn Screening',
#    'ParentId': -1,
#    'TranslationId': '30549'},
#   {'Type': 'Topic',
#    'Id': '30550',
#    'Title': 'Breastfeed Your Baby',
#    'ParentId': -1,
#    'TranslationId': '30550'},
#   {'Type': 'Topic',
#    'Id': '30551',
#    'Title': 'Watch Your Weight',
#    'ParentId': -1,
#    'TranslationId': '30551'},
#   {'Type': 'Topic',
#    'Id': '30558',
#    'Title': 'Drink Alcohol Only in Moderation',
#    'ParentId': -1,
#    'TranslationId': '30558'},
#   {'Type': 'Topic',
#    'Id': '30559',
#    'Title': 'Eat Less Sodium: Quick Tips',
#    'ParentId': -1,
#    'TranslationId': '30559'},
#   {'Type': 'Topic',
#    'Id': '30560',
#    'Title': 'Manage Stress',
#    'ParentId': -1,
#    'TranslationId': '30560'},
#   {'Type': 'Topic',
#    'Id': '30561',
#    'Title': 'Reduce Your Risk of Stroke',
#    'ParentId': -1,
#    'TranslationId': '30561'},
#   {'Type': 'Topic',
#    'Id': '30562',
#    'Title': 'Talk with Your Teen About Preventing STDs',
#    'ParentId': -1,
#    'TranslationId': '30562'},
#   {'Type': 'Topic',
#    'Id': '30564',
#    'Title': 'Get Tested for HIV',
#    'ParentId': -1,
#    'TranslationId': '30564'},
#   {'Type': 'Topic',
#    'Id': '30565',
#    'Title': 'Protect Yourself from Hepatitis B',
#    'ParentId': -1,
#    'TranslationId': '30565'},
#   {'Type': 'Topic',
#    'Id': '30566',
#    'Title': 'Help Your Child Stay at a Healthy Weight',
#    'ParentId': -1,
#    'TranslationId': '30566'},
#   {'Type': 'Topic',
#    'Id': '30567',
#    'Title': 'Get Your Medicare Wellness Visit Every Year',
#    'ParentId': -1,
#    'TranslationId': '30567'},
#   {'Type': 'Topic',
#    'Id': '30574',
#    'Title': 'Gestational Diabetes Screening: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30574'},
#   {'Type': 'Topic',
#    'Id': '30575',
#    'Title': 'Hepatitis C Screening: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30575'},
#   {'Type': 'Topic',
#    'Id': '30582',
#    'Title': 'Eat Healthy While Breastfeeding: Quick Tips',
#    'ParentId': -1,
#    'TranslationId': '30582'},
#   {'Type': 'Topic',
#    'Id': '30583',
#    'Title': 'Eat Healthy During Pregnancy: Quick Tips',
#    'ParentId': -1,
#    'TranslationId': '30583'},
#   {'Type': 'Topic',
#    'Id': '30584',
#    'Title': 'Genetic Testing to Learn About Your Risk of Breast and Ovarian Cancer: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30584'},
#   {'Type': 'Topic',
#    'Id': '30586',
#    'Title': 'Colorectal Cancer Screening: Conversation Starters',
#    'ParentId': -1,
#    'TranslationId': '30586'},
#   {'Type': 'Topic',
#    'Id': '30588',
#    'Title': 'Quitting Smoking: Conversation Starters',
#    'ParentId': -1,
#    'TranslationId': '30588'},
#   {'Type': 'Topic',
#    'Id': '30589',
#    'Title': 'Choosing a Doctor: Quick Tips',
#    'ParentId': -1,
#    'TranslationId': '30589'},
#   {'Type': 'Topic',
#    'Id': '30590',
#    'Title': 'Prostate Cancer Screening: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30590'},
#   {'Type': 'Topic',
#    'Id': '30591',
#    'Title': 'Oral Health for Older Adults: Quick Tips',
#    'ParentId': -1,
#    'TranslationId': '30591'},
#   {'Type': 'Topic',
#    'Id': '30592',
#    'Title': 'Lung Cancer Screening: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30592'},
#   {'Type': 'Topic',
#    'Id': '30593',
#    'Title': 'Mammograms: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30593'},
#   {'Type': 'Topic',
#    'Id': '30594',
#    'Title': 'Medicines to Prevent Heart Attack and Stroke: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30594'},
#   {'Type': 'Topic',
#    'Id': '30595',
#    'Title': 'Preventing Osteoporosis: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30595'},
#   {'Type': 'Topic',
#    'Id': '30596',
#    'Title': 'Healthy Eating: Conversation Starters',
#    'ParentId': -1,
#    'TranslationId': '30596'},
#   {'Type': 'Topic',
#    'Id': '30597',
#    'Title': 'Help a Loved One Get More Active: Quick Tips',
#    'ParentId': -1,
#    'TranslationId': '30597'},
#   {'Type': 'Topic',
#    'Id': '30598',
#    'Title': 'Losing Weight: Conversation Starters',
#    'ParentId': -1,
#    'TranslationId': '30598'},
#   {'Type': 'Topic',
#    'Id': '30599',
#    'Title': 'Lower-Sodium Foods: Shopping List',
#    'ParentId': -1,
#    'TranslationId': '30599'},
#   {'Type': 'Topic',
#    'Id': '30600',
#    'Title': 'Preventing Preeclampsia: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30600'},
#   {'Type': 'Topic',
#    'Id': '30601',
#    'Title': 'Preventing Type 2 Diabetes: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30601'},
#   {'Type': 'Topic',
#    'Id': '30602',
#    'Title': 'Heart-Healthy Foods: Shopping List',
#    'ParentId': -1,
#    'TranslationId': '30602'},
#   {'Type': 'Topic',
#    'Id': '30604',
#    'Title': 'Depression: Conversation Starters',
#    'ParentId': -1,
#    'TranslationId': '30604'},
#   {'Type': 'Topic',
#    'Id': '30605',
#    'Title': 'Heart Health: Conversation Starters',
#    'ParentId': -1,
#    'TranslationId': '30605'},
#   {'Type': 'Topic',
#    'Id': '30606',
#    'Title': 'Alcohol Use: Conversation Starters',
#    'ParentId': -1,
#    'TranslationId': '30606'},
#   {'Type': 'Topic',
#    'Id': '30607',
#    'Title': 'Calcium: Shopping List',
#    'ParentId': -1,
#    'TranslationId': '30607'},
#   {'Type': 'Topic',
#    'Id': '30608',
#    'Title': 'Healthy Snacks: Quick Tips for Parents',
#    'ParentId': -1,
#    'TranslationId': '30608'},
#   {'Type': 'Topic',
#    'Id': '30609',
#    'Title': 'Testing for Latent Tuberculosis: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30609'},
#   {'Type': 'Topic',
#    'Id': '30610',
#    'Title': 'Quit Smoking',
#    'ParentId': -1,
#    'TranslationId': '30610'},
#   {'Type': 'Topic',
#    'Id': '30612',
#    'Title': 'Testing for Syphilis: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30612'},
#   {'Type': 'Topic',
#    'Id': '30613',
#    'Title': 'HIV Testing: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30613'},
#   {'Type': 'Topic',
#    'Id': '30614',
#    'Title': 'STD Testing: Conversation Starters',
#    'ParentId': -1,
#    'TranslationId': '30614'},
#   {'Type': 'Topic',
#    'Id': '30615',
#    'Title': 'Losing Weight: Questions for the Doctor',
#    'ParentId': -1,
#    'TranslationId': '30615'},
#   {'Type': 'Topic',
#    'Id': '30616',
#    'Title': 'Stay Active As You Get Older: Quick Tips',
#    'ParentId': -1,
#    'TranslationId': '30616'},
#   {'Type': 'Topic',
#    'Id': '30617',
#    'Title': 'Stay Active During Pregnancy: Quick Tips',
#    'ParentId': -1,
#    'TranslationId': '30617'},
#   {'Type': 'Topic',
#    'Id': '30618',
#    'Title': 'Stay Active with a Disability: Quick Tips',
#    'ParentId': -1,
#    'TranslationId': '30618'},
#   {'Type': 'Topic',
#    'Id': '30759',
#    'Title': 'Preventing Falls: Conversation Starters',
#    'ParentId': -1,
#    'TranslationId': '30759'},
#   {'Type': 'Topic',
#    'Id': '30760',
#    'Title': 'Support a Loved One at the Doctor: Quick Tips',
#    'ParentId': -1,
#    'TranslationId': '30760'},
#   {'Type': 'Topic',
#    'Id': '33303',
#    'Title': 'Talk with Your Doctor About Drug Misuse',
#    'ParentId': -1,
#    'TranslationId': '33303'},
#   {'Type': 'Topic',
#    'Id': '33304',
#    'Title': 'Drug Misuse: Conversation starters',
#    'ParentId': -1,
#    'TranslationId': '33304'}]}

# %%
# El listado de temas que es una lista de diccionarios es convertido en un dataframe.
items = data_json['Result']['Items']

item = items['Item']

df = pd.DataFrame(item)

df.head()
# Out:
#     Type   Id                                              Title  ParentId  \
# 0  Topic   25                            Keep Your Heart Healthy        -1
# 1  Topic  327                              Get Enough Folic Acid        -1
# 2  Topic  329                         Lower Your Risk of Falling        -1
# 3  Topic  350             Get Tested for Chlamydia and Gonorrhea        -1
# 4  Topic  510  Make the Most of Your Baby’s Visit to the Doct...        -1
#
#   TranslationId
# 0            25
# 1           327
# 2           329
# 3           350
# 4           510

# %%
df.shape
# Out:
# (100, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           100 non-null    object
#  1   Id             100 non-null    object
#  2   Title          100 non-null    object
#  3   ParentId       100 non-null    int64
#  4   TranslationId  100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %% [markdown]
# ### Consulta del listado de tópicos pero en Español

# %%
url = 'https://health.gov/myhealthfinder/api/v3/itemlist.json?Type=topic&Lang=es&Lang=es'

data = rq.get(url)

data_json = json.loads(data.text)

data_json
# Out:
# {'Result': {'Error': 'False',
#   'Total': 100,
#   'Query': {'ApiVersion': '3',
#    'ApiType': 'itemlist',
#    'TopicId': None,
#    'ToolId': None,
#    'CategoryId': None,
#    'PopulationId': None,
#    'Keyword': None,
#    'Who': None,
#    'Age': None,
#    'Sex': None,
#    'Pregnant': None,
#    'TobaccoUse': None,
#    'SexuallyActive': None,
#    'Category': None,
#    'Lang': 'es',
#    'Type': 'topic',
#    'ReturnType': 'json',
#    'Callback': None,
#    'HealthfinderPage': None,
#    'APiType': 'itemlist'},
#   'Language': 'Spanish',
#   'Items': {'Item': [{'Type': 'Topic',
#      'Id': '25',
#      'Title': 'Mantén sano a tu corazón ',
#      'ParentId': -1,
#      'TranslationId': '25'},
#     {'Type': 'Topic',
#      'Id': '327',
#      'Title': 'Toma suficiente ácido fólico ',
#      'ParentId': -1,
#      'TranslationId': '327'},
#     {'Type': 'Topic',
#      'Id': '329',
#      'Title': 'Reduce el riesgo de sufrir caídas',
#      'ParentId': -1,
#      'TranslationId': '329'},
#     {'Type': 'Topic',
#      'Id': '350',
#      'Title': 'Hazte las pruebas para detectar la infección por clamidia y la gonorrea',
#      'ParentId': -1,
#      'TranslationId': '350'},
#     {'Type': 'Topic',
#      'Id': '510',
#      'Title': 'Saca el mayor provecho de la visita de tu bebé al doctor (desde el nacimiento hasta los 11 meses de edad) ',
#      'ParentId': -1,
#      'TranslationId': '510'},
#     {'Type': 'Topic',
#      'Id': '512',
#      'Title': 'Saca el mayor provecho de las consultas de tu hijo con el doctor (de 1 a 4 años)',
#      'ParentId': -1,
#      'TranslationId': '512'},
#     {'Type': 'Topic',
#      'Id': '514',
#      'Title': 'Hazte la prueba para detectar el cáncer de seno',
#      'ParentId': -1,
#      'TranslationId': '514'},
#     {'Type': 'Topic',
#      'Id': '527',
#      'Title': 'Saca el mayor provecho de la visita de tu hijo al doctor (de 5 a 10 años de edad)',
#      'ParentId': -1,
#      'TranslationId': '527'},
#     {'Type': 'Topic',
#      'Id': '528',
#      'Title': 'Saca el mayor provecho de la visita de tu niño al doctor (de 11 a 14 años de edad)',
#      'ParentId': -1,
#      'TranslationId': '528'},
#     {'Type': 'Topic',
#      'Id': '529',
#      'Title': 'Saca el mayor provecho de la visita de tu hijo adolescente con el doctor (de 15 a 17 años de edad)',
#      'ParentId': -1,
#      'TranslationId': '529'},
#     {'Type': 'Topic',
#      'Id': '530',
#      'Title': 'Cómo cuidar los dientes de tu hijo',
#      'ParentId': -1,
#      'TranslationId': '530'},
#     {'Type': 'Topic',
#      'Id': '531',
#      'Title': 'Hazte las pruebas de detección',
#      'ParentId': -1,
#      'TranslationId': '531'},
#     {'Type': 'Topic',
#      'Id': '532',
#      'Title': 'Habla con el doctor sobre el aneurisma aórtico abdominal',
#      'ParentId': -1,
#      'TranslationId': '532'},
#     {'Type': 'Topic',
#      'Id': '533',
#      'Title': 'Hazte tomar la presión arterial',
#      'ParentId': -1,
#      'TranslationId': '533'},
#     {'Type': 'Topic',
#      'Id': '534',
#      'Title': 'Hazte la prueba para medir la densidad de los huesos',
#      'ParentId': -1,
#      'TranslationId': '534'},
#     {'Type': 'Topic',
#      'Id': '536',
#      'Title': 'Hazte la prueba de detección del cáncer de cuello uterino',
#      'ParentId': -1,
#      'TranslationId': '536'},
#     {'Type': 'Topic',
#      'Id': '537',
#      'Title': 'Hazte la prueba del colesterol',
#      'ParentId': -1,
#      'TranslationId': '537'},
#     {'Type': 'Topic',
#      'Id': '538',
#      'Title': 'Hazte las pruebas de detección del cáncer colorrectal',
#      'ParentId': -1,
#      'TranslationId': '538'},
#     {'Type': 'Topic',
#      'Id': '539',
#      'Title': 'La detección de la depresión en los adolescentes',
#      'ParentId': -1,
#      'TranslationId': '539'},
#     {'Type': 'Topic',
#      'Id': '540',
#      'Title': 'Habla con tu doctor sobre la depresión',
#      'ParentId': -1,
#      'TranslationId': '540'},
#     {'Type': 'Topic',
#      'Id': '541',
#      'Title': 'Lleva a tus hijos a que le examinen los ojos',
#      'ParentId': -1,
#      'TranslationId': '541'},
#     {'Type': 'Topic',
#      'Id': '542',
#      'Title': 'Adulto mayor: vacúnate para proteger tu salud (personas de 50 años o más)',
#      'ParentId': -1,
#      'TranslationId': '542'},
#     {'Type': 'Topic',
#      'Id': '543',
#      'Title': 'Vacúnate para proteger tu salud (adultos de 19 a 49 años de edad)',
#      'ParentId': -1,
#      'TranslationId': '543'},
#     {'Type': 'Topic',
#      'Id': '544',
#      'Title': 'Vacuna a tu niño contra el VPH ',
#      'ParentId': -1,
#      'TranslationId': '544'},
#     {'Type': 'Topic',
#      'Id': '546',
#      'Title': 'Asegúrate de que tu niño esté al día en las vacunas',
#      'ParentId': -1,
#      'TranslationId': '546'},
#     {'Type': 'Topic',
#      'Id': '547',
#      'Title': 'Habla con el doctor si hay cáncer de seno o de ovario en tu familia',
#      'ParentId': -1,
#      'TranslationId': '547'},
#     {'Type': 'Topic',
#      'Id': '549',
#      'Title': 'Asegúrate de que tu preadolescente esté al día en sus vacunas ',
#      'ParentId': -1,
#      'TranslationId': '549'},
#     {'Type': 'Topic',
#      'Id': '551',
#      'Title': 'Protégete de la gripe (influenza) estacional ',
#      'ParentId': -1,
#      'TranslationId': '551'},
#     {'Type': 'Topic',
#      'Id': '552',
#      'Title': 'Toma las riendas del cuidado de tu salud ',
#      'ParentId': -1,
#      'TranslationId': '552'},
#     {'Type': 'Topic',
#      'Id': '553',
#      'Title': 'Preguntas para el doctor: la prueba de detección del cáncer colorrectal',
#      'ParentId': -1,
#      'TranslationId': '553'},
#     {'Type': 'Topic',
#      'Id': '30530',
#      'Title': 'Toma suficiente calcio ',
#      'ParentId': -1,
#      'TranslationId': '30530'},
#     {'Type': 'Topic',
#      'Id': '30531',
#      'Title': 'Cuida de tu salud en la vejez ',
#      'ParentId': -1,
#      'TranslationId': '30531'},
#     {'Type': 'Topic',
#      'Id': '30532',
#      'Title': 'Toma medidas para prevenir el cáncer de piel',
#      'ParentId': -1,
#      'TranslationId': '30532'},
#     {'Type': 'Topic',
#      'Id': '30533',
#      'Title': 'Duerme lo suficiente',
#      'ParentId': -1,
#      'TranslationId': '30533'},
#     {'Type': 'Topic',
#      'Id': '30534',
#      'Title': 'Busca apoyo si eres cuidador',
#      'ParentId': -1,
#      'TranslationId': '30534'},
#     {'Type': 'Topic',
#      'Id': '30535',
#      'Title': 'Habla con tus hijos sobre el tabaco, el alcohol y las drogas',
#      'ParentId': -1,
#      'TranslationId': '30535'},
#     {'Type': 'Topic',
#      'Id': '30536',
#      'Title': 'Toma medidas para prevenir la diabetes de tipo 2',
#      'ParentId': -1,
#      'TranslationId': '30536'},
#     {'Type': 'Topic',
#      'Id': '30537',
#      'Title': 'Presta atención a las señales de alerta sobre la violencia en la relación de pareja',
#      'ParentId': -1,
#      'TranslationId': '30537'},
#     {'Type': 'Topic',
#      'Id': '30538',
#      'Title': 'Cómo escoger el anticonceptivo adecuado ',
#      'ParentId': -1,
#      'TranslationId': '30538'},
#     {'Type': 'Topic',
#      'Id': '30539',
#      'Title': 'Come una alimentación saludable',
#      'ParentId': -1,
#      'TranslationId': '30539'},
#     {'Type': 'Topic',
#      'Id': '30540',
#      'Title': 'Realiza tu “visita de control de la mujer sana” todos los años',
#      'ParentId': -1,
#      'TranslationId': '30540'},
#     {'Type': 'Topic',
#      'Id': '30541',
#      'Title': 'Hombres: tomen control de su salud',
#      'ParentId': -1,
#      'TranslationId': '30541'},
#     {'Type': 'Topic',
#      'Id': '30542',
#      'Title': 'Habla con tus hijos sobre el sexo y las relaciones saludables',
#      'ParentId': -1,
#      'TranslationId': '30542'},
#     {'Type': 'Topic',
#      'Id': '30543',
#      'Title': 'Prevenir el dolor de espalda ',
#      'ParentId': -1,
#      'TranslationId': '30543'},
#     {'Type': 'Topic',
#      'Id': '30544',
#      'Title': 'Habla con el doctor acerca de tomar aspirina para prevenir enfermedades',
#      'ParentId': -1,
#      'TranslationId': '30544'},
#     {'Type': 'Topic',
#      'Id': '30545',
#      'Title': 'Evita las infecciones cuando recibas atención médica ',
#      'ParentId': -1,
#      'TranslationId': '30545'},
#     {'Type': 'Topic',
#      'Id': '30546',
#      'Title': 'Toma los medicamentos de forma segura',
#      'ParentId': -1,
#      'TranslationId': '30546'},
#     {'Type': 'Topic',
#      'Id': '30547',
#      'Title': 'Mantente activo',
#      'ParentId': -1,
#      'TranslationId': '30547'},
#     {'Type': 'Topic',
#      'Id': '30548',
#      'Title': 'Disfruta de un embarazo saludable ',
#      'ParentId': -1,
#      'TranslationId': '30548'},
#     {'Type': 'Topic',
#      'Id': '30549',
#      'Title': 'Habla con el doctor sobre las pruebas de detección que necesitan los recién nacidos ',
#      'ParentId': -1,
#      'TranslationId': '30549'},
#     {'Type': 'Topic',
#      'Id': '30550',
#      'Title': 'Amamanta a tu bebé (dale el pecho)',
#      'ParentId': -1,
#      'TranslationId': '30550'},
#     {'Type': 'Topic',
#      'Id': '30551',
#      'Title': 'Mantente en un peso saludable',
#      'ParentId': -1,
#      'TranslationId': '30551'},
#     {'Type': 'Topic',
#      'Id': '30558',
#      'Title': 'Si tomas alcohol, hazlo con moderación',
#      'ParentId': -1,
#      'TranslationId': '30558'},
#     {'Type': 'Topic',
#      'Id': '30559',
#      'Title': 'Consejos: Cómo comer menos sodio',
#      'ParentId': -1,
#      'TranslationId': '30559'},
#     {'Type': 'Topic',
#      'Id': '30560',
#      'Title': 'Controla el estrés',
#      'ParentId': -1,
#      'TranslationId': '30560'},
#     {'Type': 'Topic',
#      'Id': '30561',
#      'Title': 'Reduce el riesgo de tener un derrame cerebral',
#      'ParentId': -1,
#      'TranslationId': '30561'},
#     {'Type': 'Topic',
#      'Id': '30562',
#      'Title': 'Habla con tu hijo adolescente sobre cómo prevenir las enfermedades de transmisión sexual',
#      'ParentId': -1,
#      'TranslationId': '30562'},
#     {'Type': 'Topic',
#      'Id': '30564',
#      'Title': 'Hazte la prueba del VIH',
#      'ParentId': -1,
#      'TranslationId': '30564'},
#     {'Type': 'Topic',
#      'Id': '30565',
#      'Title': 'Protégete de la hepatitis B',
#      'ParentId': -1,
#      'TranslationId': '30565'},
#     {'Type': 'Topic',
#      'Id': '30566',
#      'Title': 'Ayuda a tu hijo o hija a mantenerse en un peso saludable',
#      'ParentId': -1,
#      'TranslationId': '30566'},
#     {'Type': 'Topic',
#      'Id': '30567',
#      'Title': 'Programa tu visita preventiva de Medicare todos los años',
#      'ParentId': -1,
#      'TranslationId': '30567'},
#     {'Type': 'Topic',
#      'Id': '30574',
#      'Title': 'Preguntas para el doctor: La prueba de la diabetes gestacional ',
#      'ParentId': -1,
#      'TranslationId': '30574'},
#     {'Type': 'Topic',
#      'Id': '30575',
#      'Title': 'La prueba de detección de la hepatitis C: preguntas para el doctor',
#      'ParentId': -1,
#      'TranslationId': '30575'},
#     {'Type': 'Topic',
#      'Id': '30582',
#      'Title': 'Consejos: Cómo comer una alimentación saludable durante la lactancia materna ',
#      'ParentId': -1,
#      'TranslationId': '30582'},
#     {'Type': 'Topic',
#      'Id': '30583',
#      'Title': 'Consejos: Cómo comer alimentos saludables durante el embarazo ',
#      'ParentId': -1,
#      'TranslationId': '30583'},
#     {'Type': 'Topic',
#      'Id': '30584',
#      'Title': 'Preguntas para el doctor: Las pruebas genéticas para saber qué riesgo corres de sufrir cáncer de seno y ovario ',
#      'ParentId': -1,
#      'TranslationId': '30584'},
#     {'Type': 'Topic',
#      'Id': '30586',
#      'Title': 'Temas para hablar con un ser querido: La prueba de detección del cáncer de colon y de recto ',
#      'ParentId': -1,
#      'TranslationId': '30586'},
#     {'Type': 'Topic',
#      'Id': '30588',
#      'Title': 'Temas para hablar con un ser querido: Dejar de fumar',
#      'ParentId': -1,
#      'TranslationId': '30588'},
#     {'Type': 'Topic',
#      'Id': '30589',
#      'Title': 'Consejos: cómo escoger un doctor',
#      'ParentId': -1,
#      'TranslationId': '30589'},
#     {'Type': 'Topic',
#      'Id': '30590',
#      'Title': 'Preguntas para el doctor: la prueba de detección del cáncer de próstata',
#      'ParentId': -1,
#      'TranslationId': '30590'},
#     {'Type': 'Topic',
#      'Id': '30591',
#      'Title': 'La salud de la boca para las personas mayores: consejos rápidos',
#      'ParentId': -1,
#      'TranslationId': '30591'},
#     {'Type': 'Topic',
#      'Id': '30592',
#      'Title': 'Preguntas para el doctor: La prueba de detección del cáncer de pulmón ',
#      'ParentId': -1,
#      'TranslationId': '30592'},
#     {'Type': 'Topic',
#      'Id': '30593',
#      'Title': 'Las mamografías: preguntas para el doctor',
#      'ParentId': -1,
#      'TranslationId': '30593'},
#     {'Type': 'Topic',
#      'Id': '30594',
#      'Title': 'Medicamentos para prevenir el ataque al corazón y el derrame cerebral: preguntas para el doctor',
#      'ParentId': -1,
#      'TranslationId': '30594'},
#     {'Type': 'Topic',
#      'Id': '30595',
#      'Title': 'Preguntas para el doctor: Cómo prevenir la osteoporosis ',
#      'ParentId': -1,
#      'TranslationId': '30595'},
#     {'Type': 'Topic',
#      'Id': '30596',
#      'Title': 'Temas para hablar con un ser querido: La alimentación saludable',
#      'ParentId': -1,
#      'TranslationId': '30596'},
#     {'Type': 'Topic',
#      'Id': '30597',
#      'Title': 'Ayuda a un ser querido a ser más activo: consejos rápidos',
#      'ParentId': -1,
#      'TranslationId': '30597'},
#     {'Type': 'Topic',
#      'Id': '30598',
#      'Title': 'Temas para hablar con un ser querido: Bajar de peso',
#      'ParentId': -1,
#      'TranslationId': '30598'},
#     {'Type': 'Topic',
#      'Id': '30599',
#      'Title': 'Lista para llevar al mercado: Alimentos que contienen menos sodio',
#      'ParentId': -1,
#      'TranslationId': '30599'},
#     {'Type': 'Topic',
#      'Id': '30600',
#      'Title': 'Preguntas para el doctor: ¿Cómo prevenir la preeclampsia? ',
#      'ParentId': -1,
#      'TranslationId': '30600'},
#     {'Type': 'Topic',
#      'Id': '30601',
#      'Title': 'Previniendo la diabetes tipo 2: preguntas para el doctor ',
#      'ParentId': -1,
#      'TranslationId': '30601'},
#     {'Type': 'Topic',
#      'Id': '30602',
#      'Title': 'Lista para llevar al mercado: Alimentos para tener un corazón sano',
#      'ParentId': -1,
#      'TranslationId': '30602'},
#     {'Type': 'Topic',
#      'Id': '30604',
#      'Title': 'Temas para hablar con un ser querido: La depresión ',
#      'ParentId': -1,
#      'TranslationId': '30604'},
#     {'Type': 'Topic',
#      'Id': '30605',
#      'Title': 'La salud del corazón: cómo iniciar la conversación',
#      'ParentId': -1,
#      'TranslationId': '30605'},
#     {'Type': 'Topic',
#      'Id': '30606',
#      'Title': 'Temas para hablar con un ser querido: El consumo de alcohol ',
#      'ParentId': -1,
#      'TranslationId': '30606'},
#     {'Type': 'Topic',
#      'Id': '30607',
#      'Title': 'Lista para llevar al mercado: Alimentos que contienen calcio ',
#      'ParentId': -1,
#      'TranslationId': '30607'},
#     {'Type': 'Topic',
#      'Id': '30608',
#      'Title': 'Consejos para los padres: Meriendas o refrigerios saludables ',
#      'ParentId': -1,
#      'TranslationId': '30608'},
#     {'Type': 'Topic',
#      'Id': '30609',
#      'Title': 'Preguntas para el doctor: La prueba de la tuberculosis latente',
#      'ParentId': -1,
#      'TranslationId': '30609'},
#     {'Type': 'Topic',
#      'Id': '30610',
#      'Title': 'Deja de fumar',
#      'ParentId': -1,
#      'TranslationId': '30610'},
#     {'Type': 'Topic',
#      'Id': '30612',
#      'Title': 'Preguntas para el doctor: La prueba de la sífilis',
#      'ParentId': -1,
#      'TranslationId': '30612'},
#     {'Type': 'Topic',
#      'Id': '30613',
#      'Title': 'Preguntas para el doctor: La prueba del VIH',
#      'ParentId': -1,
#      'TranslationId': '30613'},
#     {'Type': 'Topic',
#      'Id': '30614',
#      'Title': 'Las pruebas para detectar enfermedades de transmisión sexual: cómo iniciar la conversación',
#      'ParentId': -1,
#      'TranslationId': '30614'},
#     {'Type': 'Topic',
#      'Id': '30615',
#      'Title': 'Preguntas para el doctor: Bajar de peso',
#      'ParentId': -1,
#      'TranslationId': '30615'},
#     {'Type': 'Topic',
#      'Id': '30616',
#      'Title': 'Mantente activo con el paso de los años: consejos rápidos',
#      'ParentId': -1,
#      'TranslationId': '30616'},
#     {'Type': 'Topic',
#      'Id': '30617',
#      'Title': 'Mantente activa durante el embarazo: consejos rápidos',
#      'ParentId': -1,
#      'TranslationId': '30617'},
#     {'Type': 'Topic',
#      'Id': '30618',
#      'Title': 'Mantente activo si tienes una discapacidad: consejos rápidos',
#      'ParentId': -1,
#      'TranslationId': '30618'},
#     {'Type': 'Topic',
#      'Id': '30759',
#      'Title': 'La prevención de caídas: cómo iniciar la conversación',
#      'ParentId': -1,
#      'TranslationId': '30759'},
#     {'Type': 'Topic',
#      'Id': '30760',
#      'Title': 'Consejos: Cómo apoyar a un ser querido cuando tiene que ir al doctor',
#      'ParentId': -1,
#      'TranslationId': '30760'},
#     {'Type': 'Topic',
#      'Id': '33303',
#      'Title': 'Habla con el doctor sobre el consumo indebido de drogas',
#      'ParentId': -1,
#      'TranslationId': '33303'},
#     {'Type': 'Topic',
#      'Id': '33304',
#      'Title': 'El consumo indebido de drogas: cómo iniciar la conversación ',
#      'ParentId': -1,
#      'TranslationId': '33304'}]}}}

# %% [markdown]
# Aquí se observa que devuelve el mismo listado de tópicos pero en español.

# %% [markdown]
# ### Consulta a un tópico en particular

# %% [markdown]
# A continuación se van a visualizar algunas de las keys mas importantes del JSON devuelto.

# %%
url = 'https://health.gov/myhealthfinder/api/v3/topicsearch.json?TopicId=527'

data = rq.get(url)

data_json = json.loads(data.text)

data_json
# Out:
# {'Result': {'Error': 'False',
#   'Total': 1,
#   'Query': {'ApiVersion': '3',
#    'ApiType': 'topicsearch',
#    'TopicId': '527',
#    'ToolId': None,
#    'CategoryId': None,
#    'PopulationId': None,
#    'Keyword': None,
#    'Who': None,
#    'Age': None,
#    'Sex': None,
#    'Pregnant': None,
#    'TobaccoUse': None,
#    'SexuallyActive': None,
#    'Category': None,
#    'Lang': 'en',
#    'Type': None,
#    'ReturnType': 'json',
#    'Callback': None,
#    'HealthfinderPage': None,
#    'APiType': 'topicsearch'},
#   'Language': 'English',
#   'Resources': {'Resource': [{'Type': 'Topic',
#      'Id': '527',
#      'Title': 'Make the Most of Your Child’s Visit to the Doctor (Ages 5 to 10)',
#      'TranslationId': '527',
#      'TranslationTitle': '',
#      'Categories': 'Checkups for Children and Teens',
#      'Populations': '',
#      'MyHFTitle': '',
#      'MyHFDescription': '',
#      'MyHFCategory': '',
#      'MyHFCategoryHeading': '',
#      'LastUpdate': '1658435717',
#      'ImageUrl': 'https://health.gov/sites/default/files/2020-01/shutterstock_272136395_0.jpg',
#      'ImageAlt': 'Health care provider using a stethoscope on a young girl while her mother watches',
#      'AccessibleVersion': 'https://health.gov/myhealthfinder/doctor-visits/regular-checkups/make-most-your-childs-visit-doctor-ages-5-10',
#      'RelatedItems': {'RelatedItem': [{'Type': 'Topic',
#         'Id': '30608',
#         'Title': 'Healthy Snacks: Quick Tips for Parents',
#         'Url': 'https://health.gov/myhealthfinder/healthy-living/nutrition/healthy-snacks-quick-tips-parents'},
#        {'Type': 'Topic',
#         'Id': '30566',
#         'Title': 'Help Your Child Stay at a Healthy Weight',
#         'Url': 'https://health.gov/myhealthfinder/health-conditions/obesity/help-your-child-stay-healthy-weight'},
#        {'Type': 'Topic',
#         'Id': '30542',
#         'Title': 'Talk to Your Kids About Sex and Healthy Relationships',
#         'Url': 'https://health.gov/myhealthfinder/healthy-living/sexual-health/talk-your-kids-about-sex-and-healthy-relationships'},
#        {'Type': 'Topic',
#         'Id': '541',
#         'Title': 'Get Your Child’s Vision Checked',
#         'Url': 'https://health.gov/myhealthfinder/doctor-visits/screening-tests/get-your-childs-vision-checked'},
#        {'Type': 'Topic',
#         'Id': '30535',
#         'Title': 'Talk to Your Kids About Tobacco, Alcohol, and Drugs',
#         'Url': 'https://health.gov/myhealthfinder/healthy-living/mental-health-and-relationships/talk-your-kids-about-tobacco-alcohol-and-drugs'},
#        {'Type': 'Topic',
#         'Id': '530',
#         'Title': "Take Care of Your Child's Teeth",
#         'Url': 'https://health.gov/myhealthfinder/doctor-visits/regular-checkups/take-care-your-childs-teeth'}]},
#      'Sections': {'section': [{'Title': 'The Basics: Overview',
#         'Description': '',
#         'Content': '<p><span><span><span><span><span><span><span><span>Children ages 5 to 10 need to go to the doctor or nurse for a “well-child visit” once a year.</span></span></span></span></span></span></span></span></p>\r\n\r\n<p><span><span><span><span><span><span><span><span>A well-child visit is when you take your child to the doctor to make sure they’re healthy and developing normally. This is different from other visits for sickness or injury.</span></span></span></span></span></span></span></span></p>\r\n\r\n<p><span><span><span><span><span><span><span><span>At a well-child visit, the doctor or nurse can help catch any problems early, when they may be easier to treat. You’ll also have a chance to ask any questions you may have about your child’s behavior or development.</span></span></span></span></span></span></span></span></p>\r\n\r\n<p><span><span><span><span><span><span><span><span>Learn what to expect so you can make the most of each visit.</span></span></span></span></span></span></span></span></p>\r\n'},
#        {'Title': 'The Basics: Child Development',
#         'Description': '',
#         'Content': '<h4>How do I know if my child is growing and developing on&nbsp;schedule?</h4>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>Your child’s doctor or nurse can help you understand how your child is developing and learning to do new things — like read or brush their teeth. These are sometimes called “developmental milestones.”</span></span></span></span></span></span></span></p>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>Developmental milestones for children ages 5 to 10 include physical, learning, and social skills — things like:</span></span></span></span></span></span></span></p>\r\n\r\n<ul>\r\n\t<li class="bodycopy"><span><span>Developing skills for success in school (like listening, paying attention, reading, and math)</span></span></li>\r\n\t<li class="bodycopy"><span><span>Taking care of their&nbsp;bodies without help&nbsp;(like bathing, brushing teeth, and getting&nbsp;dressed)</span></span></li>\r\n\t<li class="bodycopy"><span><span>Learning from mistakes or failures and trying again</span></span></li>\r\n\t<li class="bodycopy"><span><span>Helping with simple chores</span></span></li>\r\n\t<li class="bodycopy"><span><span>Following family rules</span></span></li>\r\n\t<li class="bodycopy"><span><span>Developing friendships and getting along with other children</span></span></li>\r\n\t<li class="bodycopy"><span><span>Participating in activities like&nbsp;school clubs, sports teams, or music lessons</span></span></li>\r\n</ul>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>See a complete list of developmental milestones for kids who are:</span></span></span></span></span></span></span></p>\r\n\r\n<ul>\r\n\t<li class="bodycopy"><a href="https://health.gov/myhealthfinder/api/outlink/topicsearch.json/https/www.cdc.gov/ncbddd/actearly/milestones/milestones-5yr.html?_label_=Age+5">Age 5</a></li>\r\n\t<li><span><span><span><span><span><a href="https://health.gov/myhealthfinder/api/outlink/topicsearch.json/http/www.cdc.gov/ncbddd/childdevelopment/positiveparenting/middle.html?_label_=Ages+6+to+8">Ages 6 to 8</a></span></span></span></span></span></li>\r\n\t<li><span><span><span><span><span><a href="https://health.gov/myhealthfinder/api/outlink/topicsearch.json/http/www.cdc.gov/ncbddd/childdevelopment/positiveparenting/middle2.html?_label_=Ages+9+to+11">Ages 9 to 11</a></span></span></span></span></span></li>\r\n</ul>\r\n'},
#        {'Title': 'Take Action: Get Ready',
#         'Description': '',
#         'Content': '<p>Take these steps to help you and your child get the most out of well-child visits.</p>\r\n\r\n<h4>Gather important information.</h4>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>Take any medical records you have to the appointment, including a record of vaccines (shots) your child has received. If your child gets special services at school because of a health condition or disability, bring that paperwork, too.</span></span></span></span></span></span></span></p>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>Make a list of any important changes in your child’s life since the last doctor’s visit, like a:</span></span></span></span></span></span></span></p>\r\n\r\n<ul>\r\n\t<li class="bodycopy"><span><span>New brother or sister</span></span></li>\r\n\t<li class="bodycopy"><span><span>Separation or divorce&nbsp;— or a parent spending time in jail or prison</span></span></li>\r\n\t<li class="bodycopy"><span><span>New school or a move to a new neighborhood</span></span></li>\r\n\t<li class="bodycopy"><span><span>Serious illness or death of a friend or family member </span></span></li>\r\n</ul>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>Use this tool to&nbsp;<a href="https://health.gov/myhealthfinder/api/outlink/topicsearch.json/https/phgkb.cdc.gov/FHH/html/index.html?_label_=%3Cspan%3Ekeep+track+of+your+child%E2%80%99s+family+health+history%3C%2Fspan%3E"><span>keep track of your child’s family health history</span></a>.</span></span></span></span></span></span></span></p>\r\n\r\n<h4>Help your child get more involved in doctor visits.</h4>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>You can help your child get involved by letting them know&nbsp;<span>what to expect<span class="MsoHyperlink"><span>. </span></span></span><a href="https://health.gov/myhealthfinder/api/outlink/topicsearch.json/https/kidshealth.org/en/parents/dr-visits.html?_label_=Learn+how+to+prepare+your+child+for+a+doctor+visit">Learn how to prepare your child for a doctor visit</a>.</span></span></span></span></span></span></span></p>\r\n\r\n<h5 class="bodycopy"><span><span><span><span><span><span><span>What about cost?</span></span></span></span></span></span></span></h5>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>Under the Affordable Care Act, insurance plans must cover well-child visits. Depending on your insurance plan, you may be able to get well-child visits at no cost to you. Check with your insurance company to find out more.</span></span></span></span></span></span></span></p>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>Your child may also qualify for free or low-cost health insurance through Medicaid or the Children’s Health Insurance Program (CHIP). <a href="https://health.gov/myhealthfinder/api/outlink/topicsearch.json/https/www.insurekidsnow.gov/coverage/index.html?_label_=Learn+about+coverage+options">Learn about coverage options</a> for your family.</span></span></span></span></span></span></span></p>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>If you don’t have insurance, you may still be able to get free or low-cost well-child visits. <a href="https://health.gov/myhealthfinder/api/outlink/topicsearch.json/https/findahealthcenter.hrsa.gov/?_label_=Find+a+health+center+near+you">Find a health center near you</a> and ask about well-child visits.</span></span></span></span></span></span></span></p>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>To learn more, check out these resources:</span></span></span></span></span></span></span></p>\r\n\r\n<ul>\r\n\t<li class="bodycopy"><span><span><span><span><span><span><span><a href="https://health.gov/myhealthfinder/api/outlink/topicsearch.json/https/www.healthcare.gov/preventive-care-children/?_label_=Free+preventive+care+for+children+covered+by+the+Affordable+Care+Act">Free preventive care for c ...
#        {'Title': 'Take Action: Ask Questions',
#         'Description': '',
#         'Content': '<h4>Make a list of questions you want to ask the doctor.</h4>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>Before the well-child visit, write down 3 to 5 questions you have. This visit is a great time to ask the doctor or nurse any questions about:</span></span></span></span></span></span></span></p>\r\n\r\n<ul>\r\n\t<li class="bodycopy"><span><span>A health condition your child has (like asthma, allergies, or a speech problem)</span></span></li>\r\n\t<li class="bodycopy"><span><span>Changes in behavior or mood</span></span></li>\r\n\t<li class="bodycopy"><span><span>Problems in school —&nbsp;with learning or with other children</span></span></li>\r\n</ul>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>Here are some important questions to ask:</span></span></span></span></span></span></span></p>\r\n\r\n<ul>\r\n\t<li class="bodycopy"><span><span>Is my child up&nbsp;to&nbsp;date on vaccines?</span></span></li>\r\n\t<li class="bodycopy"><span><span>How can I make sure my child is getting enough physical activity?</span></span></li>\r\n\t<li class="bodycopy"><span><span>How can I help my child eat healthy?</span></span></li>\r\n\t<li class="bodycopy"><span><span>Is my child at a healthy weight?</span></span></li>\r\n\t<li class="bodycopy"><span><span>How can I teach my child to use the internet safely?</span></span></li>\r\n\t<li class="bodycopy"><span><span>How can I talk with my child about bullying?</span></span></li>\r\n\t<li class="bodycopy"><span><span>How can I help my child know what to expect during puberty?</span></span></li>\r\n</ul>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>Take a notepad, smartphone, or tablet and write down the answers so you can remember them&nbsp;later.</span></span></span></span></span></span></span></p>\r\n\r\n<h5>Ask what to do if your child gets sick.</h5>\r\n\r\n<p><span><span><span><span><span><span><span>Make sure you know how to get in touch with a doctor or nurse when the office is closed. Ask how to get hold of the doctor on call, or if there\'s a nurse&nbsp;information service you can call at night or on the weekend.&nbsp;</span></span></span></span></span></span></span></p>\r\n'},
#        {'Title': 'Take Action: What to Expect',
#         'Description': '',
#         'Content': '<h4>Know what to expect.</h4>\r\n\r\n<p><span><span><span><span><span><span><span>During each well-child visit, the doctor or nurse will ask you questions about your child, do a physical exam, and&nbsp;update your child’s medical history. You\'ll also be able to ask your questions and discuss any problems.&nbsp;</span></span></span></span></span></span></span></p>\r\n\r\n<h4>The doctor or nurse will ask you and your child questions.</h4>\r\n\r\n<p>The doctor or nurse may ask about:</p>\r\n\r\n<ul>\r\n\t<li class="bodycopy"><span><span>Behavior — Does your child have trouble following directions at home or at&nbsp;school?</span></span></li>\r\n\t<li class="bodycopy"><span><span>Health — Does your child often complain of headaches or other&nbsp;pain?</span></span></li>\r\n\t<li class="bodycopy"><span><span>School — Does your child look forward to going to school?</span></span></li>\r\n\t<li class="bodycopy"><span><span>Activities&nbsp;— What does your child like to do after school and on weekends?</span></span></li>\r\n\t<li class="bodycopy"><span><span>Eating habits — What does your child eat on a normal day?</span></span></li>\r\n\t<li class="bodycopy"><span><span>Family — Have there been any changes in your family since your last&nbsp;visit?</span></span></li>\r\n</ul>\r\n\r\n<p class="bodycopy"><span><span>They may also ask questions about safety, like:</span></span></p>\r\n\r\n<ul>\r\n\t<li class="bodycopy"><span><span>Does your child always ride in the back seat of the car?</span></span></li>\r\n\t<li class="bodycopy"><span><span>Does anyone in your home have a gun? If so, is it unloaded and locked in a place where your child can’t get it?</span></span></li>\r\n\t<li class="bodycopy"><span><span>Is there a swimming pool or other water around your home?</span></span></li>\r\n</ul>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span>Your answers to questions like these will help the doctor or nurse make sure your child is healthy, safe, and developing normally.</span></span></span></span></span></span></span></p>\r\n'},
#        {'Title': 'Take Action: Physical Exam',
#         'Description': '',
#         'Content': '<h4>The doctor or nurse will also check your child’s body.</h4>\r\n\r\n<p>To check your child’s body, the doctor or nurse will:</p>\r\n\r\n<ul>\r\n\t<li class="bodycopy"><span><span>Measure your child’s height and weight</span></span></li>\r\n\t<li class="bodycopy"><span><span>Check your child’s blood pressure</span></span></li>\r\n\t<li class="bodycopy"><span><span>Check your child’s vision&nbsp;and hearing</span></span></li>\r\n\t<li class="bodycopy"><span><span>Check your child’s body parts&nbsp;(this is called a physical exam)</span></span></li>\r\n\t<li class="bodycopy"><span><span>Give your child shots they need</span></span></li>\r\n</ul>\r\n\r\n<p class="bodycopy"><span><span><span><span><span><span><span><span><span>Learn more about your child’s health care.</span></span></span></span></span></span></span></span></span></p>\r\n\r\n<ul>\r\n\t<li><span><span><span><a href="https://health.gov/myhealthfinder/api/outlink/topicsearch.json/https/health.gov/myhealthfinder/topics/doctor-visits/shots-vaccines/get-your-childs-shots-schedule?_label_=%3Cspan%3EFind+out+how+to+get+your+child%E2%80%99s+shots+on+schedule%3C%2Fspan%3E"><span>Find out how to get your child’s shots on schedule</span></a></span></span></span></li>\r\n\t<li><span><span><span><a href="https://health.gov/myhealthfinder/api/outlink/topicsearch.json/https/health.gov/myhealthfinder/topics/doctor-visits/screening-tests/get-your-childs-vision-checked?_label_=%3Cspan%3ELearn+about+getting+your+child%E2%80%99s+vision+checked%3C%2Fspan%3E"><span>Learn about getting your child’s vision checked</span></a></span></span></span></li>\r\n</ul>\r\n'}]},
#      'MoreInfoItems': None,
#      'HealthfinderLogo': 'https://health.gov/themes/custom/healthfinder/images/MyHF.svg',
#      'HealthfinderUrl': 'https://health.gov/myhealthfinder'}]}}}

# %%
# Verifico que el JSON no tiene errores.
data_json['Result']['Error']
# Out:
# 'False'

# %%
# Verifico el idioma del JSON.
data_json['Result']['Language']
# Out:
# 'English'

# %%
# Muestro el título de tópico.
data_json['Result']['Resources']['Resource'][0]['Title']
# Out:
# 'Make the Most of Your Child’s Visit to the Doctor (Ages 5 to 10)'

# %%
# Muestro la categoría del tema.
data_json['Result']['Resources']['Resource'][0]['Categories']
# Out:
# 'Checkups for Children and Teens'

# %%
# Muestro la fecha del creación del tópico.
data_json['Result']['Resources']['Resource'][0]['LastUpdate']
# Out:
# '1658435717'

# %%
# Como la fecha está en timestamp la paso a calendario gregoriano.
ft = data_json['Result']['Resources']['Resource'][0]['LastUpdate']
fecha = pd.to_datetime(ft, unit="s")
fecha
# Out:
# Timestamp('2022-07-21 20:35:17')

# %%
# Obtengo la url de la imágen del tema.
url_img = data_json['Result']['Resources']['Resource'][0]['ImageUrl']

# %%
# Como lo que se obtiene de la imagen del tópico es la url, no la imagen en sí, si se desea verla a la misma se
# debe importar la librería PIL. La imagen a ser visualizada se abre aparte del notebook en otra ventana(cuando 
# se trabaja en un notebook local con Anaconda, en google Colab no funciona).
import urllib.request
from PIL import Image
  
urllib.request.urlretrieve(url_img,"imagen_tema.png")
  
img = Image.open("imagen_tema.png")

img.show()

# %%
# Obtengo el listado de los temas relacionados y los paso a un dataframe.
item = data_json['Result']['Resources']['Resource'][0]['RelatedItems']['RelatedItem']

df = pd.DataFrame(item)

df
# Out:
#     Type     Id                                              Title  \
# 0  Topic  30608             Healthy Snacks: Quick Tips for Parents
# 1  Topic  30566           Help Your Child Stay at a Healthy Weight
# 2  Topic  30542  Talk to Your Kids About Sex and Healthy Relati...
# 3  Topic    541                    Get Your Child’s Vision Checked
# 4  Topic  30535  Talk to Your Kids About Tobacco, Alcohol, and ...
# 5  Topic    530                    Take Care of Your Child's Teeth
#
#                                                  Url
# 0  https://health.gov/myhealthfinder/healthy-livi...
# 1  https://health.gov/myhealthfinder/health-condi...
# 2  https://health.gov/myhealthfinder/healthy-livi...
# 3  https://health.gov/myhealthfinder/doctor-visit...
# 4  https://health.gov/myhealthfinder/healthy-livi...
# 5  https://health.gov/myhealthfinder/doctor-visit...

# %%
df.shape
# Out:
# (6, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Type    6 non-null      object
#  1   Id      6 non-null      object
#  2   Title   6 non-null      object
#  3   Url     6 non-null      object
# dtypes: object(4)
# memory usage: 320.0+ bytes

# %% [markdown]
# ### Resumen

# %% [markdown]
# De la API seleccionada para trabajar quizas no se pudo hacer calculos estadisticos o graficar alguna data importante pero si se pudo llevar a cabo algunas cosas interesantes como formatear fecha, convertir un listado de diccionarios en una dataframe, abrir una imagen y acceder a información que puede llegar a ser de utilidad como el título, la fecha de creación o el listado de temas relacionados.
