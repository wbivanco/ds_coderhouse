# %% [markdown]
# ## Datasets - Temática: salud

# %% [markdown]
# ##### Los datasets que serán utilizados en el notebook tienen como temática la salud, los mismos fueron desacargados de https://www.datos.gob.ar que es el sitio oficial del gobierno de la República Argentina
#
# * El primer dataset versa sobre el listado de fallecidos mensual entre el 2015 y el 2020.
# * El segundo dataset trata sobre el listado de vacunados contra el COVID19 en la República Argentina.
# * EL útlimo dataset muestra el listado contagiados de COVID19 en la República Argentina.
#
#
#
# **El repositorio con los datasets y notebooks que se van a utilizar en el proyecto final del curso estan ubicados en:**

# %%
import pandas as pd

# %% [markdown]
# ### Fallecimientos

# %% [markdown]
# #### El dataset muestra el listado de fallecidos en la República Argantina entre el 2015 y el 2020. Dentro del mismo se pueden destacar los campos:
# * grupo etario
# * sexo
# * jurisdicción
# * cauda de defunción

# %%
fallecidos = pd.read_csv('datasets/fallecidos.csv')

fallecidos.head()
# Out:
#      region    jurisdiccion mes_anio_defuncion  mes_def  anio_def  sexo_id  \
# 0  1.Centro  6.Prov. Bs.As.            09/2015        9      2015        1
# 1  1.Centro  6.Prov. Bs.As.            09/2015        9      2015        1
# 2  1.Centro  6.Prov. Bs.As.            08/2015        8      2015        1
# 3  1.Centro  6.Prov. Bs.As.            05/2015        5      2015        1
# 4  1.Centro  6.Prov. Bs.As.            10/2015       10      2015        1
#
#   sexo_nombre         grupo_etario  \
# 0   1.Varones  01.menor a 20 anios
# 1   1.Varones  01.menor a 20 anios
# 2   1.Varones  01.menor a 20 anios
# 3   1.Varones  01.menor a 20 anios
# 4   1.Varones  01.menor a 20 anios
#
#                          grupo_causa_defuncion_CIE10 cod_causa_muerte_CIE10  \
# 0                            1500 AFECC  PERINATALES                    P21
# 1  1600 MALFORM  CONGENITAS, DEFORM  Y ANOM  CROM...                    Q60
# ...

# %%
fallecidos.shape
# Out:
# (100000, 11)

# %%
fallecidos.columns
# Out:
# Index(['region', 'jurisdiccion', 'mes_anio_defuncion', 'mes_def', 'anio_def',
#        'sexo_id', 'sexo_nombre', 'grupo_etario', 'grupo_causa_defuncion_CIE10',
#        'cod_causa_muerte_CIE10', 'cantidad'],
#       dtype='object')

# %%
# La forma original del dataframe era de (2079985, 11), como son muchos registros y para no ralentizar el notebook, 
# se crea un subset con los 100.000 primeros registros del dataframe. Este conjunto de datos serán los que se van 
# a utilizar en el proyecto. Para realizar esa reduccíon se ejecutaron los siguientes comandos:

#df_fallecidos = fallecidos.iloc[0:100000]
#df_fallecidos.shape
#df_fallecidos.to_csv('datasets/fallecidos.csv', index=False)

# %% [markdown]
# ### COVID 19

# %% [markdown]
# #### Vacunados

# %% [markdown]
# #### El dataset muestra el listado de vacunados en la República Argantina. Dentro del mismo se pueden destacar los campos:
# * edad
# * sexo
# * proevincia de residencia
# * fecha de diagnóstico

# %%
vacunados_covid = pd.read_csv('datasets/vacunados.csv')

vacunados_covid.head()
# Out:
#   sexo grupo_etario jurisdiccion_residencia  jurisdiccion_residencia_id  \
# 0    F        12-17                 Mendoza                          50
# 1    M          <12                    CABA                           2
# 2    F        70-79                  Chubut                          26
# 3    F        60-69            Buenos Aires                           6
# 4    M          <12            Buenos Aires                           6
#
#   depto_residencia  depto_residencia_id jurisdiccion_aplicacion  \
# 0       Guaymallén                   28                 Mendoza
# 1         COMUNA 3                    3                    CABA
# 2           Biedma                    7                  Chubut
# 3  Lomas de Zamora                  490            Buenos Aires
# 4          Quilmes                  658            Buenos Aires
#
#    jurisdiccion_aplicacion_id    depto_aplicacion  depto_aplicacion_id  \
# 0                          50          Guaymallén                   28
# ...

# %%
vacunados_covid.shape
# Out:
# (100000, 17)

# %%
vacunados_covid.columns
# Out:
# Index(['sexo', 'grupo_etario', 'jurisdiccion_residencia',
#        'jurisdiccion_residencia_id', 'depto_residencia', 'depto_residencia_id',
#        'jurisdiccion_aplicacion', 'jurisdiccion_aplicacion_id',
#        'depto_aplicacion', 'depto_aplicacion_id', 'fecha_aplicacion', 'vacuna',
#        'cod_dosis_generica', 'nombre_dosis_generica', 'condicion_aplicacion',
#        'orden_dosis', 'lote_vacuna'],
#       dtype='object')

# %%
# La forma original del dataframe era de (105916221, 17), como son muchos registros y para no ralentizar el notebook, 
# se crea un subset con los 100.000 primeros registros del dataframe. Este conjunto de datos serán los que se van 
# a utilizar en el proyecto. Para realizar esa reduccíon se ejecutaron los siguientes comandos:

#df_vacunados = vacunados_covid.iloc[0:100000]
#df_vacunados.shape
#df_vacunados.to_csv('datasets/vacunados.csv', index=False)

# %% [markdown]
# #### Contagiados

# %% [markdown]
# #### El dataset muestra el listado de los contagiados en la República Argantina. Dentro del mismo se pueden destacar los campos:
# * edad
# * sexo
# * provincia de residencia
# * fecha de diagnóstico

# %%
contagiados_covid = pd.read_csv('datasets/contagiados.csv')

contagiados_covid.head()
# Out:
#    id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 0         1000000    M  55.0            Años              Argentina
# 1        10000000    F  53.0            Años              Argentina
# 2        10000001    F  23.0            Años              Argentina
# 3        10000002    F  45.0            Años              Argentina
# 4        10000003    F  34.0            Años              Argentina
#
#   residencia_provincia_nombre residencia_departamento_nombre  \
# 0                        CABA                SIN ESPECIFICAR
# 1                        CABA                SIN ESPECIFICAR
# 2                Buenos Aires                Lomas de Zamora
# 3                Buenos Aires                     La Matanza
# 4                        CABA                      COMUNA 01
#
#   carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  ...  \
# 0           Buenos Aires                   NaN     2020-06-01  ...
# ...

# %%
contagiados_covid.shape
# Out:
# (100000, 25)

# %%
contagiados_covid.columns
# Out:
# Index(['id_evento_caso', 'sexo', 'edad', 'edad_años_meses',
#        'residencia_pais_nombre', 'residencia_provincia_nombre',
#        'residencia_departamento_nombre', 'carga_provincia_nombre',
#        'fecha_inicio_sintomas', 'fecha_apertura', 'sepi_apertura',
#        'fecha_internacion', 'cuidado_intensivo', 'fecha_cui_intensivo',
#        'fallecido', 'fecha_fallecimiento', 'asistencia_respiratoria_mecanica',
#        'carga_provincia_id', 'origen_financiamiento', 'clasificacion',
#        'clasificacion_resumen', 'residencia_provincia_id', 'fecha_diagnostico',
#        'residencia_departamento_id', 'ultima_actualizacion'],
#       dtype='object')

# %%
# La forma original del dataframe era de (29971992, 25), como son muchos registros y para no ralentizar el notebook, 
# se crea un subset con los 100.000 primeros registros del dataframe. Este conjunto de datos serán los que se van 
# a utilizar en el proyecto. Para realizar esa reduccíon se ejecutaron los siguientes comandos:

#df_contagiados = contagiados_covid.iloc[0:100000]
#df_contagiados.shape
#df_contagiados.to_csv('datasets/contagiados.csv', index=False)
